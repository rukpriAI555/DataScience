# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset = pd.read_csv("Placement.csv")

# %%
#dataset

# %%
#Separating quantitative data and qualitative data using a function written in the class Univariate

# %%
from Univariate import Univariate
quan, qual = Univariate.QuanQual(dataset)
print("quan", quan)
print("qual", qual)
# Out:
# quan ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# qual ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
#Univariate.FreqTable("hsc_p", dataset)

# %%
#  Viewing the Descriptive table using the function written in Univariate class
descriptive = Univariate.univariate(dataset, quan)

# %%
descriptive
# Out:
#               sl_no       ssc_p       hsc_p   degree_p     etest_p      mba_p  \
# Mean          108.0   67.303395   66.333163  66.370186   72.100558  62.278186
# Median        108.0        67.0        65.0       66.0        71.0       62.0
# Mode              1        62.0        63.0       65.0        60.0       56.7
# Q1:25%         54.5        60.6        60.9       61.0        60.0     57.945
# Q2:50%        108.0        67.0        65.0       66.0        71.0       62.0
# Q3:75%        161.5        75.7        73.0       72.0        83.5     66.255
# 99%          212.86        87.0       91.86      83.86        97.0    76.1142
# Q4:100%       215.0        89.4        97.7       91.0        98.0      77.89
# IQR           107.0        15.1        12.1       11.0        23.5       8.31
# 1.5Rule       160.5       22.65       18.15       16.5       35.25     12.465
# Lesser       -106.0       37.95       42.75       44.5       24.75      45.48
# ...

# %%
# 3. Find outliers using a function written in the class
#lesser, greater = Univariate.Finding_outliers(descriptive, quan)

# %%
# 4. Display result
#print("Lesser Outliers:", lesser)
#print("Greater Outliers:", greater)

# %%
# Replace outliers using a function written in the class
#Univariate.Handle_outliers(dataset, descriptive, quan)

# %%
# 3. Checking if outliers exist after replacing outliers
#lesser, greater = Univariate.Finding_outliers(descriptive, quan)

# %%
# 4. Display result
#print("Lesser Outliers:", lesser)
#print("Greater Outliers:", greater)

# %%
#print(dataset["hsc_p"].min())
#print(descriptive["hsc_p"]["Lesser"])
#print(dataset["hsc_p"].max())
#print(descriptive["hsc_p"]["Greater"])
#print(dataset["degree_p"].max())
#print(descriptive["degree_p"]["Greater"])
#print(dataset["salary"].max())
#print(descriptive["salary"]["Greater"])

# %%
# 3. Find outliers
lesser, greater = Univariate.Finding_outliers(descriptive, quan)

print("Before Handling")
print("Lesser:", lesser)
print("Greater:", greater)

# 4. Handle/replace outliers
dataset = Univariate.Handle_outliers(dataset, descriptive, quan)

# 5. Recalculate descriptive statistics, dataframe table with replaced values
descriptive = Univariate.univariate(dataset, quan)

# 6. Check outliers again
lesser, greater = Univariate.Finding_outliers(descriptive, quan)

print("\nAfter Handling")
print("Lesser:", lesser)
print("Greater:", greater)
descriptive
# Out:
# Before Handling
# Lesser: ['hsc_p']
# Greater: ['hsc_p', 'degree_p', 'salary']
#
# After Handling
# Lesser: []
# Greater: []
#               sl_no       ssc_p       hsc_p   degree_p     etest_p      mba_p  \
# Mean          108.0   67.303395   66.334744  66.358558   72.100558  62.278186
# Median        108.0        67.0        65.0       66.0        71.0       62.0
# Mode              1        62.0        63.0       65.0        60.0       56.7
# Q1:25%         54.5        60.6        60.9       61.0        60.0     57.945
# Q2:50%        108.0        67.0        65.0       66.0        71.0       62.0
# Q3:75%        161.5        75.7        73.0       72.0        83.5     66.255
# 99%          212.86        87.0      91.129      83.86        97.0    76.1142
# Q4:100%       215.0        89.4       91.15       88.5        98.0      77.89
# IQR           107.0        15.1        12.1       11.0        23.5       8.31
# ...

# %%
#Finding Frequency information for a column; using a function in the written class
Univariate.FreqTable("hsc_p", dataset)
# Out:
#     Unique_values  Frequency  Relative Frequency    Cumsum
# 0           63.00        NaN                 NaN       NaN
# 1           62.00        NaN                 NaN       NaN
# 2           60.00        NaN                 NaN       NaN
# 3           67.00        NaN                 NaN       NaN
# 4           70.00        NaN                 NaN       NaN
# ..            ...        ...                 ...       ...
# 86          70.29        1.0            0.004651  0.688372
# 87          83.83        2.0            0.009302  0.697674
# 88          70.40        NaN                 NaN       NaN
# 89          90.90        NaN                 NaN       NaN
# 90          61.33        2.0            0.009302  0.706977
#
# [91 rows x 4 columns]
