# %%
import pandas as pd

# %%
dataset = pd.read_csv("preplacement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#dir(dataset)

# %%
def QuanQual(dataset):
    quan = []
    qual = []
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtypes=='O'):
            qual.append(columnName)
        else:
            quan.append(columnName)
    return quan, qual

# %%
quan, qual = QuanQual(dataset)

# %%
#df = pd.DataFrame(columns = quan)

# %%
#df

# %%
dataset.cov(numeric_only=True)
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
dataset.corr(numeric_only=True)
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
#pairplot will provide graph of the dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
pair_plot = sns.pairplot(dataset)
pair_plot.savefig("pairplot.png", dpi=300)
plt.show()

# %%
#import seaborn as sns
#sns.pairplot(dataset)

# %%
#pair_plot.savefig(r"C:\Users\YourName\Desktop\pairplot.png", dpi=300)

# %%
pair_plot.savefig("pairplot.png", dpi=300, bbox_inches="tight") #Dots Per Inch

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(x):
    #calculating vif
    vif = pd.DataFrame()
    vif["variables"] = x.columns
    vif["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
    return (vif)

# %%
calc_vif(dataset[["ssc_p","hsc_p","degree_p", "etest_p", "mba_p", "salary"]])
# Out:
#   variables         VIF
# 0     ssc_p   76.496603
# 1     hsc_p   58.972066
# 2  degree_p  113.299298
# 3   etest_p   32.679659
# 4     mba_p  114.025972
# 5    salary    3.931112

# %%
calc_vif(dataset[["etest_p","salary"]])
# Out:
#   variables       VIF
# 0   etest_p  2.745261
# 1    salary  2.745261

# %%
def calc_vif(x):
    vif = pd.DataFrame()
    vif["variables"] = x.columns

   
    vif_values = []
    for i in range(x.shape[1]):
          value = variance_inflation_factor(x.values,i)
          vif_values.append(value)
    vif["VIF"] = vif_values 
    return (vif)

# %%
calc_vif(dataset[["ssc_p","hsc_p","degree_p", "etest_p", "mba_p", "salary"]])
# Out:
#   variables         VIF
# 0     ssc_p   76.496603
# 1     hsc_p   58.972066
# 2  degree_p  113.299298
# 3   etest_p   32.679659
# 4     mba_p  114.025972
# 5    salary    3.931112

# %% [markdown]
# # T-Test - Independent Sample - unpaired test

# %%
#Different group - male and female - same condition - salary - unpaired test

# %%
#To see male dataset info

# %%
dataset[dataset["gender"]=="M"]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# To see female dataset info

# %%
dataset[dataset["gender"]=="F"]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 6        7      F  46.00   Others   49.2   Others  Commerce      79.0
# 12      13      F  47.00  Central   55.0   Others   Science      65.0
# 13      14      F  77.00  Central   87.0  Central  Commerce      59.0
# 15      16      F  65.00  Central   75.0  Central  Commerce      69.0
# 17      18      F  55.00  Central   67.0  Central  Commerce      64.0
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 197    198      F  83.96   Others   53.0   Others   Science      91.0
# 198    199      F  67.00  Central   70.0  Central  Commerce      65.0
# 204    205      F  74.00   Others   73.0   Others  Commerce      73.0
# 208    209      F  43.00  Central   60.0   Others   Science      65.0
# 213    214      F  74.00   Others   66.0   Others  Commerce      58.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# To find male's salary

# %%
dataset[dataset["gender"]== "M"]["salary"]
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           0.0
# 4      425000.0
#          ...
# 209    216000.0
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 214         0.0
# Name: salary, Length: 139, dtype: float64

# %%
# To find female's salary

# %%
dataset[dataset["gender"]=="F"]["salary"]
# Out:
# 6           0.0
# 12          0.0
# 13     218000.0
# 15     200000.0
# 17          0.0
#          ...
# 197    260000.0
# 198         0.0
# 204    210000.0
# 208         0.0
# 213    204000.0
# Name: salary, Length: 76, dtype: float64

# %%
#Independent sample - TTest result - Unpaired - Two groups and one condition

# %%
from scipy.stats import ttest_ind
dataset = dataset.dropna()
male = dataset[dataset["gender"]== "M"]["salary"]
female = dataset[dataset["gender"]=="F"]["salary"]
ttest_ind(male, female)
# Out:
# TtestResult(statistic=np.float64(2.1103433958668765), pvalue=np.float64(0.03599560646745178), df=np.float64(213.0))

# %%
# we can accept 5% of pvalue, in this case it is 3% acceptable; similarity is more, difference is less

# %%
#Assignment - ssc_b ("Others" and "Central") - salary

# %%
from scipy.stats import ttest_ind
dataset = dataset.dropna()
sscothers = dataset[dataset["ssc_b"]== "Others"]["salary"]
ssccentral = dataset[dataset["ssc_b"]=="Central"]["salary"]
ttest_ind(sscothers, ssccentral)
# Out:
# TtestResult(statistic=np.float64(0.505185285363673), pvalue=np.float64(0.6139510180995318), df=np.float64(213.0))

# %%
# pvalue is 61%, so not acceptable, more differences lesser similarity

# %% [markdown]
# # Dependent Sample - Paired T-Test

# %%
#Same group(male) - different conditions (ssc_p, hsc_p) - all the male candidates, how much did they get in ssc_p and hsc_p?

# %%
from scipy.stats import ttest_rel
dataset = dataset.dropna()
ssc = dataset[dataset["gender"]== "M"]["ssc_p"]
hsc = dataset[dataset["gender"]=="M"]["hsc_p"]
ttest_rel(ssc, hsc)
# Out:
# TtestResult(statistic=np.float64(0.6852881050898076), pvalue=np.float64(0.49431164600731514), df=np.int64(138))

# %%
#pvalue is 49%,  more differences and less similarity

# %%
#Assignment - commerce students (group) - conditions (mba and entrancetest)

# %%
from scipy.stats import ttest_rel
dataset = dataset.dropna()
mba = dataset[dataset["hsc_s"]== "Commerce"]["mba_p"]
etest = dataset[dataset["hsc_s"]== "Commerce"]["etest_p"]
ttest_rel(mba, etest)
# Out:
# TtestResult(statistic=np.float64(-7.868552092606871), pvalue=np.float64(2.462926468454984e-12), df=np.int64(112))

# %%
# pvalue is high; differences are more and similarities are less

# %% [markdown]
# # Hypothesis Testing

# %%
# Statement: Test whether ssc_p of male and hsc_p of male is same

# %%
# Null Hypothesis: There is no similarity between 10th pass mark of male and 12th pass mark of male

# %%
from scipy.stats import ttest_rel
dataset = dataset.dropna()
ssc = dataset[dataset["gender"]== "M"]["ssc_p"]
hsc = dataset[dataset["gender"]=="M"]["hsc_p"]
ttest_rel(ssc, hsc)
# Out:
# TtestResult(statistic=np.float64(0.6852881050898076), pvalue=np.float64(0.49431164600731514), df=np.int64(138))

# %%
# if pvalue<0.05 reject null hypothesis and accept alternate hypothesis
# if pvalue>0.05 accept null hypothesis and reject alternate hypothesis

# %%
# Here, pvalue is > 0.05, accept null hypothesis and reject alternate hypothesis

# %% [markdown]
# # Hands-on ANAVO

# %%
#variance level between marks - ssc_p, hsc_p and degree_p - One way classification

# %%
import scipy.stats as stats
stats.f_oneway(dataset["ssc_p"], dataset["hsc_p"], dataset["degree_p"])
# Out:
# F_onewayResult(statistic=np.float64(0.6719700864663096), pvalue=np.float64(0.5110602818995302))

# %%
# if pvalue<0.05, reject null hypothesis and accept alternate hypothesis

# %%
#since pvalue>0.05, accept null hypothesis and reject alternate hypothesis

# %%
print ("ANAVO")
# Out:
# ANAVO

# %%
#variance level between gender, degree and salary - Two way classification, 2 categorical - gender, degree and 1 numerical - salary

# %%
import statsmodels.api as sm 
from statsmodels.formula.api import ols
model = ols('salary ~ C(gender)*C(degree_t)', data = dataset).fit()
anova_result = sm.stats.anova_lm(model, typ=2)
print(anova_result)
# Out:
#                              sum_sq     df         F    PR(>F)
# C(gender)              8.583162e+10    1.0  3.691936  0.056036
# C(degree_t)            6.115226e+10    2.0  1.315192  0.270635
# C(gender):C(degree_t)  1.017579e+11    2.0  2.188492  0.114648
# Residual               4.858917e+12  209.0       NaN       NaN

# %%
#PR value is 0.114648, which is greater than 0.05, so accept null hypothesis and reject alternate hypothesis

# %% [markdown]
# #code explanation of two way classification - ANAVO
# # Import statsmodels library for statistical analysis
# import statsmodels.api as sm
#
# # Import OLS (Ordinary Least Squares) to create the ANOVA model
# from statsmodels.formula.api import ols
#
#
# # Create the Two-Way ANOVA model
# model = ols(
#     'salary ~ C(gender) * C(degree_t)',
#     data=dataset
# ).fit()
#
# # salary   → Dependent (numerical) variable
# # gender   → Factor 1 (categorical variable)
# # degree_t → Factor 2 (categorical variable)
# # C()      → Treats the variable as categorical
# # *        → Checks both factors and their interaction
# # .fit()   → Fits the model using the dataset
#
#
# # Generate the Two-Way ANOVA table
# anova_result = sm.stats.anova_lm(model, typ=2)
#
# # Display the ANOVA results
# print(anova_result)
# typ = 2 Use Type II Sum of Squares to calculate the ANOVA effects.
# ~ means "is explained by" or "depends on".
